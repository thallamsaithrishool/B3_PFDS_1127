# %% [markdown]
# <a href="https://colab.research.google.com/github/thallamsaithrishool/B3_PFDS_1127/blob/main/LAB_07_1127_PFDS_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **BAR GRAPH**

# %%
import matplotlib.pyplot as plt

students = ["A","B","C","D","E"]
marks = [85,70,90,60,75]
plt.bar(students, marks, color = "blue")
plt.xlabel("Students")
plt.ylabel("Marks")
plt.title("Student Marks")
plt.show()

# %% [markdown]
# **SCATTER PLOT**

# %%
import matplotlib.pyplot as plt

hours = [2,3,4,5,6,7,8]
scores = [50,55,65,75,70,80,90]
plt.scatter(hours, scores, color = "red")
plt.xlabel("Hours")
plt.ylabel("Scores")
plt.title("Hours vs Scores")
plt.show()

# %% [markdown]
# **HISTOGRAM**

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4,5]
y = [2,4,6,8,10]
plt.plot(x,y, marker='o')
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Line Plot")
plt.show()

# %% [markdown]
# **PLOTY**

# %%
import plotly.express as px

x = [1,2,3,4,5]
y = [2,4,6,8,10]
fig = px.line(x=x, y=y, title='Line Plot')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **SEABORN**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips=sns.load_dataset("tips")
sns.barplot(x="day", y="total_bill", data=tips)
plt.title("Box plot of Totl Bill by Day")
plt.show()

# %% [markdown]
# **LAB PROGRAM 1**

# %%
import pandas as pd
import numpy as np


days = pd.to_datetime(pd.Series(range(1, 31), name='Day'), unit='D', origin='2023-01-01').dt.strftime('%Y-%m-%d')
temperatures = np.random.uniform(10, 30, size=30)

dummy_data = pd.DataFrame({'Day': days, 'Temperature': temperatures})


dummy_data.to_csv('daily_temperature.csv', index=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("daily_temperature.csv")
plt.figure(figsize=(8,6))
plt.plot(data["Day"], data["Temperature"], marker="o", linestyle="-")
plt.xlabel("Day")
plt.ylabel("Temperature (°C)")
plt.title("Daily Temperature Variation - Weather Dataset")
plt.grid(True)
plt.show()

hottest_day = data.loc[data["Temperature"].idxmax()]
coldest_day = data.loc[data["Temperature"].idxmin()]

print("Hottest Day:", hottest_day["Day"], "with", hottest_day["Temperature"], "°C")
print("Coldest Day:", coldest_day["Day"], "with", coldest_day["Temperature"], "°C")
# Out:
# Hottest Day: 2023-01-28 with 29.333009523308668 °C
# Coldest Day: 2023-01-18 with 10.38695789759463 °C

# %% [markdown]
# **LAB PROGRAM 2**

# %%
import pandas as pd

data = {'Quarter': ['Q1', 'Q2', 'Q3', 'Q4'],
        'Sales': [10000, 15000, 12000, 18000]}
sales_df = pd.DataFrame(data)
sales_df.to_csv('sales_data.csv', index=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("sales_data.csv")
plt.figure(figsize=(8,5))
plt.plot(data["Quarter"], data["Sales"], marker="o", linestyle="-", label="Sales")
peak = data.loc[data["Sales"].idxmax()]
plt.scatter(peak["Quarter"], peak["Sales"], color="red", s=100, zorder=5, label="Peak Sales")
plt.xlabel("Quarter")
plt.ylabel("Sales")
plt.title("Quarterly Sales Performance - Retail Sales Dataset")
plt.grid(True)
plt.legend()
plt.show()

print("Peak Sales occurred in", peak["Quarter"], "with sales of", peak["Sales"])
# Out:
# Peak Sales occurred in Q4 with sales of 18000
